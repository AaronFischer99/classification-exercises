# %%
import acquire
import os

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_iris
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 3
#       1 from sklearn.datasets import load_iris
# ----> 3 load_iris.data
#
# AttributeError: 'function' object has no attribute 'data'

# %%
# Load Iris dataset
iris = load_iris()
iris_df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
#iris_df['target'] = iris.target

# %%
data_titanic = pd.read_csv('titanic.csv', index_col=0)
data_titanic.head()
# Out:
#    passenger_id  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
#
#   embarked  class deck  embark_town  alone
# 0        S  Third  NaN  Southampton      0
# 1        C  First    C    Cherbourg      0
# 2        S  Third  NaN  Southampton      1
# 3        S  First    C  Southampton      0
# 4        S  Third  NaN  Southampton      1

# %%
data_titanic.dropna()
# Out:
#      Unnamed: 0  passenger_id  survived  pclass     sex   age  sibsp  parch  \
# 1             1             1         1       1  female  38.0      1      0
# 3             3             3         1       1  female  35.0      1      0
# 6             6             6         0       1    male  54.0      0      0
# 10           10            10         1       3  female   4.0      1      1
# 11           11            11         1       1  female  58.0      0      0
# ..          ...           ...       ...     ...     ...   ...    ...    ...
# 871         871           871         1       1  female  47.0      1      1
# 872         872           872         0       1    male  33.0      0      0
# 879         879           879         1       1  female  56.0      0      1
# 887         887           887         1       1  female  19.0      0      0
# 889         889           889         1       1    male  26.0      0      0
#
#         fare embarked  class deck  embark_town  alone
# ...

# %%
def prep_titanic():
    if os.path.isfile('titanic.csv'):
        df = pd.read_csv('titanic.csv', index_col=0)
        df.dropna()
    return df

# %%
#import os

#def load_iris_data():
#    if not os.path.isfile('iris_df.csv'):
        df = new_iris_data()
 #   else:
 #       df = pd.read_csv('iris_df.csv', index_col=0)
 #   return df

# %%
new_df = prep_titanic()
new_df.head(10)
# Out:
#    passenger_id  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
# 5             5         0       3    male   NaN      0      0   8.4583
# 6             6         0       1    male  54.0      0      0  51.8625
# 7             7         0       3    male   2.0      3      1  21.0750
# 8             8         1       3  female  27.0      0      2  11.1333
# 9             9         1       2  female  14.0      1      0  30.0708
#
#   embarked   class deck  embark_town  alone
# 0        S   Third  NaN  Southampton      0
# 1        C   First    C    Cherbourg      0
# 2        S   Third  NaN  Southampton      1
# ...

# %%
data_telco = pd.read_csv('df_telco.csv', index_col=0)
data_telco.head()
# Out:
#    payment_type_id  contract_type_id  internet_service_type_id customer_id  \
# 0                2                 2                         1  0002-ORFBO
# 1                2                 1                         1  0003-MKNFE
# 2                1                 1                         2  0004-TLHLJ
# 3                1                 1                         2  0011-IGKFF
# 4                2                 1                         2  0013-EXCHZ
#
#    gender  senior_citizen partner dependents  tenure phone_service  ...  \
# 0  Female               0     Yes        Yes       9           Yes  ...
# 1    Male               0      No         No       9           Yes  ...
# 2    Male               0      No         No       4           Yes  ...
# 3    Male               1     Yes         No      13           Yes  ...
# 4  Female               1     Yes         No       3           Yes  ...
#
#   tech_support streaming_tv streaming_movies paperless_billing  \
# ...

# %%
data.isna().sum()
# Out:
# payment_type_id             0
# contract_type_id            0
# internet_service_type_id    0
# customer_id                 0
# gender                      0
# senior_citizen              0
# partner                     0
# dependents                  0
# tenure                      0
# phone_service               0
# multiple_lines              0
# online_security             0
# online_backup               0
# device_protection           0
# tech_support                0
# streaming_tv                0
# streaming_movies            0
# paperless_billing           0
# monthly_charges             0
# total_charges               0
# churn                       0
# internet_service_type       0
# contract_type               0
# payment_type                0
# dtype: int64

# %%
data['internet_service_type'] =  data['internet_service_type'].fillna("Not optioned")

# %%
data.shape
# Out:
# (7043, 24)

# %%
import sklearn

# %%
from sklearn.model_selection import train_test_split

# %%
data.internet_service_type.
# Out:
# internet_service_type
# Fiber optic    3096
# DSL            2421
# Name: count, dtype: int64

# %%
iris = pd.read_csv('iris_df.csv', index_col=0)
iris.head()
# Out:
#    species_id species_name  measurement_id  sepal_length  sepal_width  \
# 0           1       setosa               1           5.1          3.5
# 1           1       setosa               2           4.9          3.0
# 2           1       setosa               3           4.7          3.2
# 3           1       setosa               4           4.6          3.1
# 4           1       setosa               5           5.0          3.6
#
#    petal_length  petal_width
# 0           1.4          0.2
# 1           1.4          0.2
# 2           1.3          0.2
# 3           1.5          0.2
# 4           1.4          0.2

# %% [markdown]
# #### Load Iris dataset
# iris = load_iris()
# iris_df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
# #iris_df['target'] = iris.target

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

def split_data(df, target_column, test_size=0.2, validate_size=0.1, random_state=42):
# def split_data(X, y, test_size=0.2, validate_size=0.1, random_state='')
    """
    Split the data into train, test, and validate datasets.

    Parameters:
    - df: DataFrame, input data
    - target_column: str, name of the target column
    - test_size: float, proportion of the data to include in the test split
    - validate_size: float, proportion of the data to include in the validation split
    - random_state: int, seed for random number generation

    Returns:
    - train, test, validate DataFrames
    """
    train, test = train_test_split(df, test_size=test_size, random_state=random_state)
    train, validate = train_test_split(train, test_size=validate_size/(1-test_size), random_state=random_state)

    return train, test, validate

if __name__ == "__main__":
    # Example usage
    data = pd.read_csv("iris_df.csv")  # Replace with your actual data file
    train_data, test_data, validate_data = split_data(data, target_column="your_target_column")

    # You can now use train_data, test_data, and validate_data in your machine learning pipeline

# %%
new_iris_df = split_data(iris_df, iris_df.target, test_size=0.2, validate_size=0.1)
new_iris_df
# Out:
# (     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
#  41                 4.5               2.3                1.3               0.3
#  116                6.5               3.0                5.5               1.8
#  22                 4.6               3.6                1.0               0.2
#  79                 5.7               2.6                3.5               1.0
#  1                  4.9               3.0                1.4               0.2
#  89                 5.5               2.5                4.0               1.3
#  84                 5.4               3.0                4.5               1.5
#  24                 4.8               3.4                1.9               0.2
#  3                  4.6               3.1                1.5               0.2
#  138                6.0               3.0                4.8               1.8
#  86                 6.7               3.1                4.7               1.5
# ...

# %%
new_titanic_df = split_data(data_titanic, data_titanic.survived, test_size=0.2, validate_size=0.1)
new_titanic_df
# Out:
# (     passenger_id  survived  pclass     sex   age  sibsp  parch     fare  \
#  382           382         0       3    male  32.0      0      0   7.9250
#  153           153         0       3    male  40.5      0      2  14.5000
#  69             69         0       3    male  26.0      2      0   8.6625
#  193           193         1       2    male   3.0      1      1  26.0000
#  106           106         1       3  female  21.0      0      0   7.6500
#  ..            ...       ...     ...     ...   ...    ...    ...      ...
#  79             79         1       3  female  30.0      0      0  12.4750
#  164           164         0       3    male   1.0      4      1  39.6875
#  117           117         0       2    male  29.0      1      0  21.0000
#  8               8         1       3  female  27.0      0      2  11.1333
#  131           131         0       3    male  20.0      0      0   7.0500
#
#      embarked   class deck  embark_town  alone
# ...

# %%
new_data_telco = split_data(data_telco, data_telco.churn, test_size=0.2, validate_size=0.1)
new_data_telco
# Out:
# (      payment_type_id  contract_type_id  internet_service_type_id customer_id  \
#  5119                1                 2                         2  7203-OYKCT
#  2170                1                 1                         3  3097-PYWXL
#  5152                1                 1                         1  7246-ZGQDF
#  5035                1                 1                         1  7078-NVFAM
#  2710                3                 2                         2  3858-XHYJO
#  ...               ...               ...                       ...         ...
#  1050                4                 3                         3  1535-VTJOQ
#  1409                1                 1                         2  2080-CAZNM
#  6834                4                 1                         1  9708-HPXWZ
#  5685                1                 1                         2  8010-EZLOU
#  6651                2                 1                         1  9462-MJUAW
#
# ...

# %% [markdown]
# #### Trial one by one
#
# from sklearn.model_selection import train_test_split
#
#
#
# def split_data(df):
#     '''
#     take in a DataFrame and return train, validate, and test DataFrames; stratify on survived.
#     return train, validate, test DataFrames.
#     '''
#     #test size
#     train_validate, test = train_test_split(df, test_size=.2, random_state=123, stratify=df.survived)
#
#     #validate size
#     train, validate = train_test_split(train_validate,
#                                        test_size=.3,
#                                        random_state=123,
#                                        stratify=train_validate.survived)
#     return train, validate, test

# %%
import pandas as pd
from sklearn.datasets import load_iris

# Load Iris dataset
iris = load_iris()
iris_df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
iris_df['target'] = iris.target

# Split the Iris dataset
train_iris, test_iris, validate_iris = split_data(iris_df, target_column="target")

# Display the shapes of the resulting datasets
print("Train Iris Shape:", train_iris.shape)
print("Test Iris Shape:", test_iris.shape)
print("Validate Iris Shape:", validate_iris.shape)
# Out:
# Train Iris Shape: (105, 5)
# Test Iris Shape: (30, 5)
# Validate Iris Shape: (15, 5)

# %%
from acquire import get_titanic_data

# %%
data_titanic = pd.read_csv('titanic.csv', index_col=0)

# %%
import pandas as pd
from acquire import get_titanic_data

# Split the Iris dataset
train_titanic, test_titanic, validate_titanic = split_data(data_titanic, target_column="survived")

# Display the shapes of the resulting datasets
print("Train  Shape:", train_titanic.shape)
print("Test  Shape:", test_titanic.shape)
print("Validate Shape:", validate_titanic.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 4
#       1 data_titanic['target'] = data_titanic['survived']
#       3 # Split the Iris dataset
# ----> 4 train_titanic, test_titanic, validate_titanic = split_data(iris_df, target_column="target")
#       6 # Display the shapes of the resulting datasets
#       7 print("Train  Shape:", train_titanic.shape)
#
# NameError: name 'split_data' is not defined

# %%
def split_data(df):
    '''
    Take in a DataFrame and return train, validate, and test DataFrames with stratification on 'survived'.
    Return train, validate, test DataFrames.
    '''
    train, test = train_test_split(df, test_size=0.2, random_state=123, stratify=df.survived)
    train, validate = train_test_split(train, test_size=0.3, random_state=123, stratify=train.survived)
    return train, validate, test

# %% [markdown]
# ### Exploratory Analysis

# %%
import pandas as pd
from sklearn.datasets import load_iris
import numpy as np
import matplotlib.pyplot as plt
import acquire
import os

# %%
from acquire import get_iris_data
from sklearn.model_selection import train_test_split

# %%
get_iris_data
# Out:
# <function acquire.get_iris_data()>

# %%
iris = pd.read_csv('iris_df.csv', index_col=0)
iris.head()
# Out:
#    species_id species_name  measurement_id  sepal_length  sepal_width  \
# 0           1       setosa               1           5.1          3.5
# 1           1       setosa               2           4.9          3.0
# 2           1       setosa               3           4.7          3.2
# 3           1       setosa               4           4.6          3.1
# 4           1       setosa               5           5.0          3.6
#
#    petal_length  petal_width
# 0           1.4          0.2
# 1           1.4          0.2
# 2           1.3          0.2
# 3           1.5          0.2
# 4           1.4          0.2

# %%
y = df["species_id"]
X = df.drop(["species_id"],axis = 1)

X_trainval, X_test, y_trainval, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)
print(X_trainval.shape,X_test.shape)

#Test len of train/test variables of y:
len(y_trainval[y_trainval == "setosa"]),len(y_trainval[y_trainval == "versicolor"]),len(y_trainval[y_trainval == "virginica"])

#split data (train data and validation data)¶
X_train, X_val, y_train, y_val = train_test_split(X_trainval, y_trainval, test_size=0.25, random_state=42, stratify=y_trainval)
print(X_train.shape,X_val.shape)

# %%
y = iris["species_id"]
X = iris.drop(["species_id"],axis = 1)

X_trainval, X_test, y_trainval, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)
print(X_trainval.shape,X_test.shape)

#Test len of train/test variables of y:
len(y_trainval[y_trainval == 1]),len(y_trainval[y_trainval == 2]),len(y_trainval[y_trainval == 3])
# Out:
# (105, 6) (45, 6)
# (35, 35, 35)

# %%
y_trainval.value_counts()
# Out:
# 2    35
# 1    35
# 3    35
# Name: species_id, dtype: int64

# %%
#split data (train data and validation data)¶
X_train, X_val, y_train, y_val = train_test_split(X_trainval, y_trainval, test_size=0.25, random_state=42, stratify=y_trainval)
print(X_train.shape,X_val.shape)
# Out:
# (78, 6) (27, 6)

# %%
import seaborn as sns

# %%
sns.histplot(iris)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.boxplot(data=iris)
plt.xticks(rotation=90);

# %%
sns.countplot(iris, x='species_id')
# Out:
# <Axes: xlabel='species_id', ylabel='count'>

# %%
iris.head()
# Out:
#    species_id species_name  measurement_id  sepal_length  sepal_width  \
# 0           1       setosa               1           5.1          3.5
# 1           1       setosa               2           4.9          3.0
# 2           1       setosa               3           4.7          3.2
# 3           1       setosa               4           4.6          3.1
# 4           1       setosa               5           5.0          3.6
#
#    petal_length  petal_width
# 0           1.4          0.2
# 1           1.4          0.2
# 2           1.3          0.2
# 3           1.5          0.2
# 4           1.4          0.2

# %%
iris.sepal_length.mean()
# Out:
# 5.843333333333334

# %%
sns.barplot(iris, x='species_id', y='sepal_length')
sns.lineplot(iris,x='species_id', y='sepal_length');

# %%
# Define the measurement types (assuming columns in your DataFrame)
measurement_types = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']

# Loop through each measurement type and create a bar plot
for measurement in measurement_types:
    plt.figure(figsize=(8, 6))
    
    # Create a bar plot
    sns.barplot(x='species_name', y=measurement, data=iris)
    
    # Add a horizontal line showing the overall mean
    overall_mean = iris[measurement].mean()
    plt.axhline(y=overall_mean, color='violet', linestyle='--', label=f'Overall Mean: {overall_mean:.2f}')
    
    # Set plot labels and title
    plt.xlabel('species_name')
    plt.ylabel(measurement.capitalize())  # Capitalize the first letter of the measurement for y-axis label
    plt.title(f'{measurement.capitalize()} by Species')
    
    # Add legend
    plt.legend()
    
    # Show the plot
    plt.show()

# %% [markdown]
# #### Results from comparison does imply that virginica species is dominant across the board for both width and length. Furthermore, rearding pedal width and pedal length, virginica was founf to be 1.5 times higher the compared average of the three species.

# %%
#For each measurement type, compute the descriptive statistics for each species.


iris[measurement_types].describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.head()
# Out:
#    species_id species_name  measurement_id  sepal_length  sepal_width  \
# 0           1       setosa               1           5.1          3.5
# 1           1       setosa               2           4.9          3.0
# 2           1       setosa               3           4.7          3.2
# 3           1       setosa               4           4.6          3.1
# 4           1       setosa               5           5.0          3.6
#
#    petal_length  petal_width
# 0           1.4          0.2
# 1           1.4          0.2
# 2           1.3          0.2
# 3           1.5          0.2
# 4           1.4          0.2

# %%
iris.species_name.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
from scipy.stats import mannwhitneyu

# %%
iris [iris['species_name'] == 'virginica'].mean()
# Out:
# /var/folders/p_/0z9srqwn3g11vvrv0s9wcxs40000gn/T/ipykernel_845/1621670176.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   iris [iris['species_name'] == 'virginica'].mean()
# species_id          3.000
# measurement_id    125.500
# sepal_length        6.588
# sepal_width         2.974
# petal_length        5.552
# petal_width         2.026
# dtype: float64

# %%
iris [iris['species_name'] == 'versicolor'].mean()
# Out:
# /var/folders/p_/0z9srqwn3g11vvrv0s9wcxs40000gn/T/ipykernel_845/3392004489.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   iris [iris['species_name'] == 'versicolor'].mean()
# species_id         2.000
# measurement_id    75.500
# sepal_length       5.936
# sepal_width        2.770
# petal_length       4.260
# petal_width        1.326
# dtype: float64

# %%
#petal_width_versicolor = iris[iris['species_name'] == 'versicolor']['petal_width']
#petal_width_virginica = iris[iris['species_name'] == 'virginica']['petal_width']


statistic, pvalue = mannwhitneyu(petal_width_versicolor, petal_width_virginica)

statistic, pvalue
# Out:
# (49.0, 9.698045444914185e-17)

# %%
mannwhitneyu(petal_width_versicolor, petal_width_virginica)

# Check for significance
alpha = 0.05
if pvalue < alpha:
    print("The difference in mean petal width is statistically significant.")
else:
    print("There is no significant difference in mean petal width between the groups.")
# Out:
# There is no significant difference in mean petal width between the groups.

# %%
petal_length_vers = iris [iris['species_name'] == 'versicolor']['petal_length']
petal_length_virg = iris [iris['species_name'] == 'virginica']['petal_length']

#Applying `mannwhitneyu` model
mannwhitneyu(petal_length_vers, petal_length_virg)

# Check for significance
alpha = 0.05
if pvalue < alpha:
    print("The difference in mean petal length is statistically significant.")
else:
    print("There is no significant difference in mean petal width between the groups.")
# Out:
# The difference in mean petal length is statistically significant.

# %%
sepal_length_vers = iris [iris['species_name'] == 'versicolor']['sepal_length']
sepal_length_virg = iris [iris['species_name'] == 'virginica']['sepal_length']

#Applying `mannwhitneyu` model
mannwhitneyu(sepal_length_vers, sepal_length_virg)

# Check for significance
alpha = 0.05
if pvalue < alpha:
    print("The difference in mean sepal length is statistically significant.")
else:
    print("There is no significant difference in mean sepal width between the groups.")
# Out:
# The difference in mean petal length is statistically significant.

# %%
sepal_width_vers = iris [iris['species_name'] == 'versicolor']['sepal_width']
sepal_width_virg = iris [iris['species_name'] == 'virginica']['sepal_width']

#Applying `mannwhitneyu` model
mannwhitneyu(sepal_width_vers, sepal_width_virg)

# Check for significance
alpha = 0.05
if pvalue < alpha:
    print("The difference in mean sepal width is statistically significant.")
else:
    print("There is no significant difference in mean sepal width between the groups.")
# Out:
# The difference in mean sepal width is statistically significant.

# %%
#4. Visualize the interaction of each measurement type with the others using a pairplot (or scatter matrix or something similar) and add color to represent species.
sns.pairplot(data=iris,hue="species_name")
#sns.pairplot(data=iris,hue="species_name", palette="husl", markers=["o", "s", "D"])
# Out:
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#Visualize two numeric variables of the species. 
#Hint: sns.relplot with hue or col

sns.relplot(iris, x='petal_length', y='sepal_length', hue='species_name');
# Out:
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
melted_iris
# Out:
#     species_name     variable  value
# 0         setosa   species_id    1.0
# 1         setosa   species_id    1.0
# 2         setosa   species_id    1.0
# 3         setosa   species_id    1.0
# 4         setosa   species_id    1.0
# ..           ...          ...    ...
# 895    virginica  petal_width    2.3
# 896    virginica  petal_width    1.9
# 897    virginica  petal_width    2.0
# 898    virginica  petal_width    2.3
# 899    virginica  petal_width    1.8
#
# [900 rows x 3 columns]

# %%
melted_iris = pd.melt(iris, id_vars='species_name', value_vars=iris.select_dtypes(include='number'), var_name='variable')

# Set the style for seaborn
sns.set(style="whitegrid")

# Create a swarmplot
plt.figure(figsize=(10, 5))
sns.swarmplot(x='variable', y='value', hue='species_name', data=melted_iris);
# Out:
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:3544: UserWarning: 90.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:3544: UserWarning: 81.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:3544: UserWarning: 76.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:3544: UserWarning: 77.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
#Ask a specific question of the data, such as: is the sepal area signficantly different in 
#virginica compared to setosa? Answer the question 
#through both a plot and using a mann-whitney or t-test. 
#If you use a t-test, be sure assumptions are met (independence, normality, equal variance).

#virg_area = pd.Series(sepal_length_virg * sepal_width_virg)
sep_area = pd.Series(sepal_length_sep * sepal_width_sep)
#sepal_width_sep = iris [iris['species_name'] == 'setosa']['sepal_width']
#sepal_length_sep = iris [iris['species_name'] == 'setosa']['sepal_length']

# %%
statistic, pvalue = mannwhitneyu(sep_area, virg_area)

# Check for significance
alpha = 0.05
if pvalue < alpha:
    print("The difference in sepal area is statistically significant.")
else:
    print("There is no significant difference in sepal area between the groups.")
# Out:
# The difference in sepal area is statistically significant.

# %% [markdown]
# ### Part 3

# %%
data_telco = pd.read_csv('df_telco.csv', index_col=0)
data_telco.shape
# Out:
# (7043, 24)

# %%
data_telco.select_dtypes(include='number').head()
# Out:
#    payment_type_id  contract_type_id  internet_service_type_id  \
# 0                2                 2                         1
# 1                2                 1                         1
# 2                1                 1                         2
# 3                1                 1                         2
# 4                2                 1                         2
#
#    senior_citizen  tenure  monthly_charges
# 0               0       9             65.6
# 1               0       9             59.9
# 2               0       4             73.9
# 3               1      13             98.0
# 4               1       3             83.9

# %%
data_telco.select_dtypes(exclude='number').head()
# Out:
#   customer_id  gender partner dependents phone_service multiple_lines  \
# 0  0002-ORFBO  Female     Yes        Yes           Yes             No
# 1  0003-MKNFE    Male      No         No           Yes            Yes
# 2  0004-TLHLJ    Male      No         No           Yes             No
# 3  0011-IGKFF    Male     Yes         No           Yes             No
# 4  0013-EXCHZ  Female     Yes         No           Yes             No
#
#   online_security online_backup device_protection tech_support streaming_tv  \
# 0              No           Yes                No          Yes          Yes
# 1              No            No                No           No           No
# 2              No            No               Yes           No           No
# 3              No           Yes               Yes           No          Yes
# 4              No            No                No          Yes          Yes
#
#   streaming_movies paperless_billing total_charges churn  \
# ...

# %%
y = data_telco["churn"]
X = data_telco.drop(["churn"],axis = 1)

X_trainval, X_test, y_trainval, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)
print(X_trainval.shape,X_test.shape)

#Test len of train/test variables of y:
len(y_trainval[y_trainval == 'Yes']),len(y_trainval[y_trainval == 'No'])

#split data (train data and validation data)¶
X_train, X_val, y_train, y_val = train_test_split(X_trainval, y_trainval, test_size=0.25, random_state=42, stratify=y_trainval)
print(X_train.shape,X_val.shape)
# Out:
# (4930, 23) (2113, 23)
# (3697, 23) (1233, 23)

# %%
sns.histplot(X_train);

# %%
#melted_telco_num = pd.melt(data_telco[:100], id_vars='churn', value_vars=data_telco.select_dtypes(include='number'), var_name='variable')
#melted_telco_num.value_counts()
melted_telco.value_counts()
# Out:
# churn  variable           value
# No     phone_service      Yes       67
#        dependents         No        50
#        paperless_billing  Yes       48
#        gender             Female    44
#        partner            Yes       43
#                                     ..
#        total_charges      1442.2     1
#                           1564.4     1
#                           1611       1
#                           1748.9     1
# Yes    total_charges      99.75      1
# Length: 281, dtype: int64

# %%
import random

rand_sample = data_telco.sample(1000)

# %%
#Boxplot of random sample of 1000 to see if depenmdents ahve an impact on monthly\
#charges, which could then lead to a result in that customer churning

# Set the style for seaborn
sns.set(style="whitegrid")

# Create a swarmplot
plt.figure(figsize=(10, 8))
sns.boxenplot(x='dependents', y='monthly_charges', hue='churn', data=rand_sample);

# %%
X_train.describe()
# Out:
#        payment_type_id  contract_type_id  internet_service_type_id  \
# count      3697.000000       3697.000000               3697.000000
# mean          2.333784          1.697052                  1.877198
# std           1.153776          0.835284                  0.733448
# min           1.000000          1.000000                  1.000000
# 25%           1.000000          1.000000                  1.000000
# 50%           2.000000          1.000000                  2.000000
# 75%           3.000000          2.000000                  2.000000
# max           4.000000          3.000000                  3.000000
#
#        senior_citizen       tenure  monthly_charges
# count     3697.000000  3697.000000       3697.00000
# mean         0.166081    32.744387         65.21911
# std          0.372203    24.635972         30.03856
# min          0.000000     0.000000         18.40000
# 25%          0.000000     9.000000         37.70000
# ...

# %%
pd.options.display.max_rows

X_train.head()
# Out:
#       payment_type_id  contract_type_id  internet_service_type_id customer_id  \
# 3409                4                 1                         3  4830-FAXFM
# 2622                1                 3                         2  3729-OWRVL
# 6756                2                 3                         2  9589-ABEPT
# 247                 1                 1                         2  0376-OIWME
# 514                 3                 2                         2  0748-RDGGM
#
#      gender  senior_citizen partner dependents  tenure phone_service  ...  \
# 3409   Male               0      No        Yes      19           Yes  ...
# 2622   Male               1      No         No      65           Yes  ...
# 6756   Male               0     Yes         No      69           Yes  ...
# 247    Male               0     Yes         No      36           Yes  ...
# 514    Male               0     Yes         No      70           Yes  ...
#
# ...

# %%
from scipy import stats

# %%
observed = pd.crosstab(X_train['contract_type'], X_train['monthly_charges'])

# %%
chi2, p, degf, expected = stats.chi2_contingency(observed)

# %%
chi2, p, degf, expected = stats.chi2_contingency(observed) 

#Conclusion based on statisitcs: 
 
if p < alpha: 
    print('There is a fiscal association between monthly charges and contract type') 
else: 
    print('We fail to reject the null hypothesis')
# Out:
# There is a fiscal association between monthly charges and contract type

# %% [markdown]
# From the data the payment type and contract type could be binned

# %% [markdown]
# From the data it could be valuable to combine monthly and total charges
# to get a more precise mean of teh customers total spent on services
